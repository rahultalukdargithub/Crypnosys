# %%
# !pip install yahooquery
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 30.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 18.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 0.21.0 requires pandas<2.1.4,>=1.5.0, but you have pandas 2.2.1 which is incompatible.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.2.1 which is incompatible.
# ...

# %%
from yahooquery import Screener
s = Screener()
data = s.get_screeners('all_cryptocurrencies_in', count=250)
# data
dicts = data['all_cryptocurrencies_in']['quotes']
dicts
symbols = [f"{d['shortName']} ({d['symbol']})" for d in dicts]
symbols_tuple = tuple(symbols)
symbols_tuple
# Out:
# ('Bitcoin INR (BTC-INR)',
#  'Ethereum INR (ETH-INR)',
#  'Tether USDt INR (USDT-INR)',
#  'BNB INR (BNB-INR)',
#  'Solana INR (SOL-INR)',
#  'XRP INR (XRP-INR)',
#  'USDC INR (USDC-INR)',
#  'Cardano INR (ADA-INR)',
#  'Avalanche INR (AVAX-INR)',
#  'Dogecoin INR (DOGE-INR)',
#  'TRON INR (TRX-INR)',
#  'Chainlink INR (LINK-INR)',
#  'Polkadot INR (DOT-INR)',
#  'Polygon INR (MATIC-INR)',
#  'Shiba Inu INR (SHIB-INR)',
#  'Uniswap INR (UNI7083-INR)',
#  'Internet Computer INR (ICP-INR)',
#  'Bitcoin Cash INR (BCH-INR)',
#  'Litecoin INR (LTC-INR)',
#  'Dai INR (DAI-INR)',
#  'Cosmos INR (ATOM-INR)',
#  'Stacks INR (STX4847-INR)',
#  'Ethereum Classic INR (ETC-INR)',
#  'Filecoin INR (FIL-INR)',
#  'Hedera INR (HBAR-INR)',
#  'VeChain INR (VET-INR)',
#  'Stellar INR (XLM-INR)',
#  'Cronos INR (CRO-INR)',
#  'The Graph INR (GRT6719-INR)',
#  'Monero INR (XMR-INR)',
#  'THORChain INR (RUNE-INR)',
#  'Maker INR (MKR-INR)',
#  'Theta Network INR (THETA-INR)',
# ...

# %%
import pandas as pd
file_path = 'my_file.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
# <ipython-input-44-11bdba1c5bb6>:7: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
#       Yahoo Stock Tickers                               Unnamed: 1 Unnamed: 2  \
# 0  http://investexcel.net                                      NaN        NaN
# 1                     NaN                                      NaN        NaN
# 2                  Ticker                                     Name   Exchange
# 3                    OEDV  Osage Exploration and Development, Inc.        PNK
# 4                    AAPL                               Apple Inc.        NMS
#
#              Unnamed: 3 Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0                   NaN        NaN         NaN         NaN
# 1                   NaN        NaN         NaN         NaN
# 2         Category Name    Country         NaN         NaN
# 3                   NaN        USA         NaN         NaN
# ...

# %%
df = df.drop(index=[0, 1])
df.head()
# Out:
#   Yahoo Stock Tickers                               Unnamed: 1 Unnamed: 2  \
# 2              Ticker                                     Name   Exchange
# 3                OEDV  Osage Exploration and Development, Inc.        PNK
# 4                AAPL                               Apple Inc.        NMS
# 5                 BAC              Bank of America Corporation        NYQ
# 6                AMZN                         Amazon.com, Inc.        NMS
#
#                     Unnamed: 3 Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 2                Category Name    Country         NaN         NaN
# 3                          NaN        USA         NaN         NaN
# 4         Electronic Equipment        USA         NaN         NaN
# 5           Money Center Banks        USA         NaN         NaN
# 6  Catalog & Mail Order Houses        USA         NaN         NaN
#
#                                     Unnamed: 7
# 2                                          NaN
# ...

# %%
df=df.reset_index(drop=True)

# %%
df.head()
# Out:
#   Yahoo Stock Tickers                               Unnamed: 1 Unnamed: 2  \
# 0              Ticker                                     Name   Exchange
# 1                OEDV  Osage Exploration and Development, Inc.        PNK
# 2                AAPL                               Apple Inc.        NMS
# 3                 BAC              Bank of America Corporation        NYQ
# 4                AMZN                         Amazon.com, Inc.        NMS
#
#                     Unnamed: 3 Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0                Category Name    Country         NaN         NaN
# 1                          NaN        USA         NaN         NaN
# 2         Electronic Equipment        USA         NaN         NaN
# 3           Money Center Banks        USA         NaN         NaN
# 4  Catalog & Mail Order Houses        USA         NaN         NaN
#
#                                     Unnamed: 7
# 0                                          NaN
# ...

# %%
df.columns = df.iloc[0]
df = df[1:]
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
# 0 Ticker                                     Name Exchange  \
# 0   OEDV  Osage Exploration and Development, Inc.      PNK
# 1   AAPL                               Apple Inc.      NMS
# 2    BAC              Bank of America Corporation      NYQ
# 3   AMZN                         Amazon.com, Inc.      NMS
# 4      T                                AT&T Inc.      NYQ
#
# 0                Category Name Country NaN NaN  \
# 0                          NaN     USA NaN NaN
# 1         Electronic Equipment     USA NaN NaN
# 2           Money Center Banks     USA NaN NaN
# 3  Catalog & Mail Order Houses     USA NaN NaN
# 4  Telecom Services - Domestic     USA NaN NaN
#
# 0                                                NaN
# 0                                         Samir Khan
# 1                     simulationconsultant@gmail.com
# 2                                                NaN
# 3        This ticker symbol list was downloaded from
# 4  http://investexcel.net/all-yahoo-finance-stock...

# %%
ticker_values = df['Ticker'].head(2000).tolist()
sticker_values = tuple(ticker_values)
print(sticker_values)
# Out:
# ('OEDV', 'AAPL', 'BAC', 'AMZN', 'T', 'GOOG', 'MO', 'DAL', 'AA', 'AXP', 'DD', 'BABA', 'ABT', 'UA', 'AMAT', 'AMGN', 'AAL', 'AIG', 'ALL', 'ADBE', 'GOOGL', 'ACN', 'ABBV', 'MT', 'LLY', 'AGN', 'APA', 'ADP', 'APC', 'AKAM', 'NLY', 'ABX', 'ATVI', 'ADSK', 'ADM', 'BMH.AX', 'WBA', 'ARNA', 'LUV', 'ACAD', 'PANW', 'AMD', 'AET', 'AEP', 'ALXN', 'CLMS', 'AVGO', 'EA', 'DB', 'RAI', 'AEM', 'APD', 'AMBA', 'NVS', 'APOL', 'ANF', 'LULU', 'RAD', 'BRK.AX', 'ARRY', 'AGNC', 'JBLU', 'A', 'ORLY', 'FOLD', 'AZO', 'ATML', 'AN', 'AZN', 'AES', 'GAS', 'BUD', 'ARR', 'BDX', 'AKS', 'AB', 'ACOR', 'CS', 'AFL', 'ADI', 'AEGR', 'ACIW', 'AMP', 'AVP', 'AMTD', 'AEO', 'AWK', 'NVO', 'ALTR', 'ALK', 'PAA', 'MTU.AX', 'ARCC', 'AAP', 'NAT', 'FNMA', 'FAV', 'AIV', 'AGIO', 'AEE', 'UBS', 'AVXL', 'ARLP', 'ANTM', 'AGU', 'AG', 'AFSI', 'ABC', 'STO', 'ATI', 'ADT', 'AVB', 'ATW', 'ALNY', 'LH', 'AVY', 'AUY', 'ASH', 'ARMH', 'ARIA', 'ANR', 'AINV', 'ACXM', 'ACHN', 'ACET', 'ABMD', 'ABM', 'VA', 'LIFE', 'ATO', 'ARP', 'AON', 'ADXS', 'ADC', 'APU', 'SAVE', '
# ...

# %%
df
# Out:
# 0       Ticker                                     Name Exchange  \
# 0         OEDV  Osage Exploration and Development, Inc.      PNK
# 1         AAPL                               Apple Inc.      NMS
# 2          BAC              Bank of America Corporation      NYQ
# 3         AMZN                         Amazon.com, Inc.      NMS
# 4            T                                AT&T Inc.      NYQ
# ...        ...                                      ...      ...
# 106323  G5N.SG          Groupon Inc. Reg. Shares DL-,00      STU
# 106324  N1H.AX                      N1 Holdings Limited      ASX
# 106325  1K2.BE                  K2M GROUP HLDGS DL-,001      BER
# 106326  2RM.BE                 RE/MAX HLDGS A DL -,0001      BER
# 106327   2RM.F                    RE/MAX Holdings, Inc.      FRA
#
# 0                     Category Name    Country NaN NaN  \
# 0                               NaN        USA NaN NaN
# 1              Electronic Equipment        USA NaN NaN
# ...

# %%
df['Formatted']=df['Name']+' '+'('+df['Ticker']+')'

# %%
df
# Out:
# 0       Ticker                                     Name Exchange  \
# 0         OEDV  Osage Exploration and Development, Inc.      PNK
# 1         AAPL                               Apple Inc.      NMS
# 2          BAC              Bank of America Corporation      NYQ
# 3         AMZN                         Amazon.com, Inc.      NMS
# 4            T                                AT&T Inc.      NYQ
# ...        ...                                      ...      ...
# 106323  G5N.SG          Groupon Inc. Reg. Shares DL-,00      STU
# 106324  N1H.AX                      N1 Holdings Limited      ASX
# 106325  1K2.BE                  K2M GROUP HLDGS DL-,001      BER
# 106326  2RM.BE                 RE/MAX HLDGS A DL -,0001      BER
# 106327   2RM.F                    RE/MAX Holdings, Inc.      FRA
#
# 0                     Category Name    Country NaN NaN  \
# 0                               NaN        USA NaN NaN
# 1              Electronic Equipment        USA NaN NaN
# ...

# %%
ticker_values = df['Formatted'].head(2000).tolist()
sticker_values = tuple(ticker_values)
print(sticker_values)
# Out:
# ('Osage Exploration and Development, Inc. (OEDV)', 'Apple Inc. (AAPL)', 'Bank of America Corporation (BAC)', 'Amazon.com, Inc. (AMZN)', 'AT&T Inc. (T)', 'Alphabet Inc. (GOOG)', 'Altria Group, Inc. (MO)', 'Delta Air Lines, Inc. (DAL)', 'Alcoa Corporation (AA)', 'American Express Company (AXP)', 'E. I. du Pont de Nemours and Company (DD)', 'Alibaba Group Holding Limited (BABA)', 'Abbott Laboratories (ABT)', 'Under Armour, Inc. (UA)', 'Applied Materials, Inc. (AMAT)', 'Amgen Inc. (AMGN)', 'American Airlines Group Inc. (AAL)', 'American International Group, Inc. (AIG)', 'The Allstate Corporation (ALL)', 'Adobe Systems Incorporated (ADBE)', 'Alphabet Inc. (GOOGL)', 'Accenture plc (ACN)', 'AbbVie Inc. (ABBV)', 'ArcelorMittal (MT)', 'Eli Lilly and Company (LLY)', 'Allergan plc (AGN)', 'Apache Corporation (APA)', 'Automatic Data Processing, Inc. (ADP)', 'Anadarko Petroleum Corporation (APC)', 'Akamai Technologies, Inc. (AKAM)', 'Annaly Capital Management, Inc. (NLY)', 'Barrick Gold Corporati
# ...

# %%
excel_file = 'yh.xlsx'
dfs = pd.read_excel(excel_file, sheet_name="Mutual Fund")

# %%
dfs
# Out:
#       Yahoo Mutual Fund Tickers                              Unnamed: 1  \
# 0        http://investexcel.net                                     NaN
# 1                           NaN                                     NaN
# 2                        Ticker                                    Name
# 3                       APU5.AX                                     NaN
# 4                  ACV1529-C.BO                                     NaN
# ...                         ...                                     ...
# 24920                     OAANX               Oppenheimer Active Allc R
# 24921             F00000WO1R.TO  IA SRP Prestige 75/100 US Divid Growth
# 24922                     EITVX              Eaton Vance Tx-Mgd Value I
# 24923                     FFIHX            American Indep US Infl-Idx I
# 24924                     SMVFX       RidgeWorth Mid-Cap Value Equity C
#
#       Unnamed: 2
# 0            NaN
# 1            NaN
# 2       Exchange
# 3            NaN
# ...

# %%
df = dfs.drop(index=[0, 1])
df.head()
# Out:
#   Yahoo Mutual Fund Tickers Unnamed: 1 Unnamed: 2
# 2                    Ticker       Name   Exchange
# 3                   APU5.AX        NaN        NaN
# 4              ACV1529-C.BO        NaN        NaN
# 5                   IRH7.AX        NaN        NaN
# 6                   WMF6.AX        NaN        NaN

# %%
df.reset_index(drop=True)
# Out:
#       Yahoo Mutual Fund Tickers                              Unnamed: 1  \
# 0                        Ticker                                    Name
# 1                       APU5.AX                                     NaN
# 2                  ACV1529-C.BO                                     NaN
# 3                       IRH7.AX                                     NaN
# 4                       WMF6.AX                                     NaN
# ...                         ...                                     ...
# 24918                     OAANX               Oppenheimer Active Allc R
# 24919             F00000WO1R.TO  IA SRP Prestige 75/100 US Divid Growth
# 24920                     EITVX              Eaton Vance Tx-Mgd Value I
# 24921                     FFIHX            American Indep US Infl-Idx I
# 24922                     SMVFX       RidgeWorth Mid-Cap Value Equity C
#
#       Unnamed: 2
# 0       Exchange
# 1            NaN
# 2            NaN
# 3            NaN
# ...

# %%
df.columns = df.iloc[0]
df = df[1:]
df = df.reset_index(drop=True)

# %%
df
# Out:
# 2             Ticker                                    Name Exchange
# 0            APU5.AX                                     NaN      NaN
# 1       ACV1529-C.BO                                     NaN      NaN
# 2            IRH7.AX                                     NaN      NaN
# 3            WMF6.AX                                     NaN      NaN
# 4           APSM6.AX                                     NaN      NaN
# ...              ...                                     ...      ...
# 24917          OAANX               Oppenheimer Active Allc R      NAS
# 24918  F00000WO1R.TO  IA SRP Prestige 75/100 US Divid Growth      TOR
# 24919          EITVX              Eaton Vance Tx-Mgd Value I      NAS
# 24920          FFIHX            American Indep US Infl-Idx I      NAS
# 24921          SMVFX       RidgeWorth Mid-Cap Value Equity C      NAS
#
# [24922 rows x 3 columns]

# %%
df['Formatted']=df['Name']+' '+'('+df['Ticker']+')'

# %%
df
# Out:
# 2             Ticker                                    Name Exchange  \
# 0            APU5.AX                                     NaN      NaN
# 1       ACV1529-C.BO                                     NaN      NaN
# 2            IRH7.AX                                     NaN      NaN
# 3            WMF6.AX                                     NaN      NaN
# 4           APSM6.AX                                     NaN      NaN
# ...              ...                                     ...      ...
# 24917          OAANX               Oppenheimer Active Allc R      NAS
# 24918  F00000WO1R.TO  IA SRP Prestige 75/100 US Divid Growth      TOR
# 24919          EITVX              Eaton Vance Tx-Mgd Value I      NAS
# 24920          FFIHX            American Indep US Infl-Idx I      NAS
# 24921          SMVFX       RidgeWorth Mid-Cap Value Equity C      NAS
#
# 2                                              Formatted
# 0                                                    NaN
# ...

# %%
filtered_df = df[df['Formatted'].notna()].tail(2500)

# Extract the 'Formatted' column values to a list
ticker_values = filtered_df['Formatted'].tolist()
# Print or use the extracted values as needed
sticker_values = tuple(ticker_values)
print(sticker_values)
# Out:
# ('Commerzbank ETC -1x Gas Oil Daily Short (X0E5.DE)', 'Fidelity Advisor Multi-Asset Income A (FWATX)', 'Goldman Sachs Income Plus WS (5024.AX)', 'American Funds Growth and Inc Port R5E (RGQFX)', 'FK ASEAN Feeder Equity-FoFs PRS (KR5235AK9717.KS)', 'SHBNPP One Belt One Road Feeder Eq 1 A1 (K55210B53423.KS)', 'Legg Mason IF QS UK Equity A Acc (GB0033506501.L)', 'JPMorgan Middle East&Africa; Fdr Eq C5 (KR5237294917.KS)', 'SHBNPP Smrt Levg Pro PF Cnv Eq-Drv FoF 5 (K55210B96026.KS)', 'Aberdeen Equity Long-Short R (GLSRX)', 'JB Clean Energy PF Spc Asst Mny Bd 1 (K55241B26309.KS)', 'Laminar Credit Opportunities Fund (LAMINARCREDI.AX)', 'Principal Blue Chip A (PBLAX)', 'DWS TOP PRF OFN T (DWWH.HM)', 'Nikko AM EG Emerg Mkts Multi Asst JPY (NIKKOAMEGEME.SI)', 'Assetplus PF Fdr Eq-Deriv 3-3 (K55364B18322.KS)', 'Quadrus Mac Cdn Large Cap Balanced Q (F0CAN05P3Z.TO)', 'DWS ZUKUNFTSRESSOUR (HJUZ.DU)', 'JHancock International Growth R4 (JIGIX)', 'UBS(LU)EF-FIN SER P (UBFF.BE)', 'Direxion Idxd Mgd Fu
# ...
